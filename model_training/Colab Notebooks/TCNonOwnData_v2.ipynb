# %%
# ==============================================================================
# TCNonOwnData_v2.ipynb
#
# Unified Training and Android Asset Export for HAR
#
# This notebook provides a complete, end-to-end pipeline:
# 1. Loads and preprocesses sensor data.
# 2. Trains a high-accuracy TCN Keras model.
# 3. Evaluates the Keras model to establish a performance benchmark.
# 4. Converts the Keras model to a high-quality, quantized TFLite model
#    suitable for Android deployment.
# 5. Exports the necessary scaler and label metadata as JSON files.
# 6. Verifies the TFLite model's accuracy to ensure the conversion was
#    successful, preventing the common accuracy drop issue.
#
# Author: Your Name
# Date: [Current Date]
# ==============================================================================

# --- Block 1: Setup and Initial Configuration ---
print("--- Block 1: Setup and Initial Configuration ---")

# Install necessary packages quietly
# !pip install joblib -q

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os
import time
import json
from pathlib import Path

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, GlobalAveragePooling1D, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.utils import class_weight

# --- Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- Main Configuration ---
# *** Define the input files using Colab paths ***
drive_base_path = Path('/content/drive/MyDrive/Colab_HAR_Project/data')
INPUT_CSV_1 = drive_base_path / 'resampled_normalized_phone_data.csv'
INPUT_CSV_2 = drive_base_path / 'combined_collected_data.csv'

ACTIVITIES_FROM_FILE1 = ['B', 'D', 'E']
ACTIVITIES_FROM_FILE2 = ['A', 'C']
ALL_ACTIVITIES_TO_KEEP = sorted(ACTIVITIES_FROM_FILE1 + ACTIVITIES_FROM_FILE2)

# *** Define a NEW output directory for this verified run ***
output_drive_path = Path('/content/drive/MyDrive/Colab_HAR_Project/results')
OUTPUT_DIR = output_drive_path / 'TCN_Results_v2_with_Assets' # New, clean directory
FILE_PREFIX = f"tcn_v2_{''.join(ALL_ACTIVITIES_TO_KEEP)}_"

# Create the output directory
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"All outputs will be saved to: {OUTPUT_DIR}")


# --- Windowing, Model, Training Parameters ---
WINDOW_SIZE = 60
STRIDE = 15
KERNEL_SIZE = 7
NUM_FILTERS = 64
NUM_TCN_BLOCKS = 5
DILATION_RATES = [2**i for i in range(NUM_TCN_BLOCKS)]
SPATIAL_DROPOUT_RATE = 0.15
FINAL_DROPOUT_RATE = 0.3
L2_REG = 1e-4
BATCH_SIZE = 64
EPOCHS = 100
VALIDATION_SPLIT = 0.2
EARLY_STOPPING_PATIENCE = 15

# --- GPU Check ---
print("\n--- GPU Check ---")
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"Found {len(gpu_devices)} GPU(s). Enabling memory growth.")
    try:
        for gpu in gpu_devices:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(f"Could not set memory growth: {e}")
else:
    print("!!! No GPU found. Training will use CPU. !!!")
print("-" * 25)

# ==============================================================================
# --- Block 2: Data Loading and Preprocessing ---
# ==============================================================================
print("\n--- Block 2: Data Loading and Preprocessing ---")

def create_subject_activity_windows(df, window_size, stride):
    windows, labels, subject_ids = [], [], []
    required_cols = ['x_accel', 'y_accel', 'z_accel', 'x_gyro', 'y_gyro', 'z_gyro']
    grouped = df.groupby(['subject', 'activity'])
    print(f"Processing {len(grouped)} subject-activity groups for windowing...")
    for name, group_df in grouped:
        data_values = group_df.sort_values('timestamp')[required_cols].values
        if len(data_values) < window_size: continue
        for start in range(0, len(data_values) - window_size + 1, stride):
            windows.append(data_values[start : start + window_size])
            labels.append(group_df["activity"].iloc[0])
            subject_ids.append(group_df["subject"].iloc[0])
    if not windows: raise ValueError("No windows created.")
    return np.array(windows), np.array(labels), np.array(subject_ids)

# --- Load and combine data ---
df1 = pd.read_csv(INPUT_CSV_1)
df2 = pd.read_csv(INPUT_CSV_2)
df1_filtered = df1[df1['activity'].isin(ACTIVITIES_FROM_FILE1)]
df2_filtered = df2[df2['activity'].isin(ACTIVITIES_FROM_FILE2)]
combined_df = pd.concat([df1_filtered, df2_filtered], ignore_index=True)
print(f"Combined dataset has {len(combined_df)} rows.")

# --- Create windows ---
X, y_raw, subjects = create_subject_activity_windows(combined_df, WINDOW_SIZE, STRIDE)
print(f"Created {len(X)} windows with shape {X.shape}")

# --- Encode labels ---
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y_raw)
num_classes = len(label_encoder.classes_)
print(f"Encoded {num_classes} classes: {list(label_encoder.classes_)}")

# --- Split data (Train/Test) ---
X_train, X_test, y_train, y_test, subjects_train, subjects_test = train_test_split(
    X, y, subjects, test_size=0.25, random_state=42, stratify=y)

# --- Scale features ---
# The scaler is fit ONLY on the training data to prevent data leakage.
# This 'scaler' object is the single source of truth for all subsequent steps.
num_samples_train, timesteps, num_features = X_train.shape
scaler = StandardScaler()
X_train_reshaped = X_train.reshape(-1, num_features)
X_train_scaled_reshaped = scaler.fit_transform(X_train_reshaped)
X_train_scaled = X_train_scaled_reshaped.reshape(num_samples_train, timesteps, num_features)

# Apply the SAME scaler to the test data
X_test_reshaped = X_test.reshape(-1, num_features)
X_test_scaled_reshaped = scaler.transform(X_test_reshaped)
X_test_scaled = X_test_scaled_reshaped.reshape(X_test.shape[0], timesteps, num_features)
print("Feature scaling complete. Scaler is fit and ready.")


# ==============================================================================
# --- Block 3: TCN Model Definition and Training ---
# ==============================================================================
print("\n--- Block 3: TCN Model Definition and Training ---")

def residual_block(x, dilation_rate, nb_filters, kernel_size, dropout_rate=0.0):
    prev_x = x
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, padding='same')(x)
    conv1 = BatchNormalization()(conv1); conv1 = Activation('relu')(conv1); conv1 = SpatialDropout1D(dropout_rate)(conv1)
    conv2 = Conv1D(filters=nb_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, padding='same')(conv1)
    conv2 = BatchNormalization()(conv2); conv2 = Activation('relu')(conv2); conv2 = SpatialDropout1D(dropout_rate)(conv2)
    if prev_x.shape[-1] != conv2.shape[-1]: prev_x = Conv1D(nb_filters, 1, padding='same')(prev_x)
    return Add()([prev_x, conv2])

def build_tcn_model(input_shape, num_classes):
    input_layer = Input(shape=input_shape)
    x = input_layer
    for rate in DILATION_RATES:
        x = residual_block(x, rate, NUM_FILTERS, KERNEL_SIZE, SPATIAL_DROPOUT_RATE)
    x = GlobalAveragePooling1D()(x)
    x = Dropout(FINAL_DROPOUT_RATE)(x)
    output_layer = Dense(num_classes, activation='softmax')(x)
    return Model(inputs=input_layer, outputs=output_layer)

model = build_tcn_model((WINDOW_SIZE, num_features), num_classes)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# --- Callbacks and Class Weights ---
checkpoint_path = OUTPUT_DIR / f'{FILE_PREFIX}har_model.keras'
model_checkpoint = ModelCheckpoint(filepath=checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=EARLY_STOPPING_PATIENCE, restore_best_weights=True, verbose=1)

class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))
print(f"Class weights computed: {class_weights_dict}")

# --- Train the model ---
history = model.fit(
    X_train_scaled, y_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    validation_split=VALIDATION_SPLIT,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    class_weight=class_weights_dict,
    verbose=1
)


# ==============================================================================
# --- Block 4: Keras Model Evaluation (Benchmark) ---
# ==============================================================================
print("\n--- Block 4: Keras Model Evaluation (Benchmark) ---")
print("Loading best Keras model weights saved during training...")
best_model = tf.keras.models.load_model(checkpoint_path)

loss, keras_accuracy = best_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"Keras Test Accuracy (Ground Truth): {keras_accuracy:.4f}")

# Generate and print classification report
y_pred_keras = np.argmax(best_model.predict(X_test_scaled), axis=1)
print("\nKeras Model Classification Report:")
print(classification_report(y_test, y_pred_keras, target_names=label_encoder.classes_))


print("\n--- Saving the definitive test set artifacts ---")
test_set_output_dir = OUTPUT_DIR / 'definitive_test_set'
test_set_output_dir.mkdir(parents=True, exist_ok=True)

# Save the scaled test data and the labels
np.save(test_set_output_dir / 'X_test_scaled.npy', X_test_scaled)
np.save(test_set_output_dir / 'y_test.npy', y_test)

print(f"Definitive test set saved to: {test_set_output_dir}")

# ==============================================================================
# --- Block 5: Exporting Assets for Android (TFLite, JSON) ---
# ==============================================================================
print("\n--- Block 5: Exporting Assets for Android (TFLite, JSON) ---")

# --- 5.1: Save Scaler as JSON ---
scaler_path_json = OUTPUT_DIR / f'{FILE_PREFIX}scaler.json'
scaler_dict = {"mean": scaler.mean_.tolist(), "scale": scaler.scale_.tolist()}
with open(scaler_path_json, 'w') as f:
    json.dump(scaler_dict, f, indent=4)
print(f"Scaler saved to: {scaler_path_json}")

# --- 5.2: Save Labels as JSON ---
labels_path_json = OUTPUT_DIR / f'{FILE_PREFIX}labels.json'
labels_dict = {str(i): label for i, label in enumerate(label_encoder.classes_)}
with open(labels_path_json, 'w') as f:
    json.dump(labels_dict, f, indent=4)
print(f"Labels saved to: {labels_path_json}")

# --- 5.3: Convert Keras model to Quantized TFLite ---
def representative_dataset_gen():
    """Yields a small, representative sample of the training data for quantization."""
    # Using the 'X_train_scaled' variable directly from memory ensures consistency.
    num_samples = min(300, len(X_train_scaled))
    for i in np.random.choice(len(X_train_scaled), num_samples, replace=False):
        yield [X_train_scaled[i:i+1].astype(np.float32)]

print("Starting TFLite conversion with full integer quantization...")
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_quant_model = converter.convert()

tflite_model_path = OUTPUT_DIR / f'{FILE_PREFIX}har_model.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_quant_model)
print(f"Quantized TFLite model saved to: {tflite_model_path}")


# ==============================================================================
# --- Block 6: TFLite Model Verification ---
# ==============================================================================
print("\n--- Block 6: TFLite Model Verification ---")
# This block simulates how the Android app would use the assets to ensure
# there is no loss in accuracy due to the conversion process.

# --- Load the TFLite model and allocate tensors ---
interpreter = tf.lite.Interpreter(model_path=str(tflite_model_path))
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

print("TFLite model loaded. Verifying performance on the test set...")
y_pred_tflite = []

# --- Loop through the test set and perform inference ---
# This mimics per-window prediction on a device.
for i in range(len(X_test)):
    # Get a single window of raw (unscaled) test data
    test_window_raw = X_test[i]

    # **Step A: Preprocessing (just like the app will do)**
    # 1. Scale the raw data using the same scaler
    test_window_scaled = scaler.transform(test_window_raw)

    # 2. Quantize the float32 data to int8 using the model's scale and zero-point
    input_scale, input_zero_point = input_details['quantization']
    test_window_quantized = (test_window_scaled / input_scale + input_zero_point).astype(np.int8)

    # **Step B: TFLite Inference**
    interpreter.set_tensor(input_details['index'], test_window_quantized[np.newaxis, ...])
    interpreter.invoke()

    # **Step C: Post-processing**
    # 1. Get the quantized output
    output_quantized = interpreter.get_tensor(output_details['index'])[0]

    # 2. De-quantize the output back to float32 probabilities
    output_scale, output_zero_point = output_details['quantization']
    output_dequantized = (output_quantized.astype(np.float32) - output_zero_point) * output_scale

    y_pred_tflite.append(np.argmax(output_dequantized))

# --- Calculate TFLite accuracy ---
y_pred_tflite = np.array(y_pred_tflite)
tflite_accuracy = accuracy_score(y_test, y_pred_tflite)

print(f"\nTFLite Model Test Accuracy: {tflite_accuracy:.4f}")
print("\nTFLite Model Classification Report:")
print(classification_report(y_test, y_pred_tflite, target_names=label_encoder.classes_))


# ==============================================================================
# --- Block 7: Final Report ---
# ==============================================================================
print("\n--- Block 7: Final Report ---")
print("="*40)
print("  VERIFICATION AND ACCURACY REPORT")
print("="*40)
print(f"Original Keras Model Accuracy: {keras_accuracy:.4f}")
print(f"Quantized TFLite Model Accuracy: {tflite_accuracy:.4f}")
accuracy_drop = keras_accuracy - tflite_accuracy
print(f"Accuracy Drop: {accuracy_drop:.4f} ({accuracy_drop*100:.2f}%)")

if accuracy_drop < 0.02:
    print("\nVERDICT: SUCCESS! The TFLite model's accuracy is very close to the original.")
    print("The assets are consistent and ready for deployment.")
else:
    print("\nVERDICT: WARNING! The accuracy drop is larger than expected (>2%).")
    print("Review the model architecture or quantization process.")
print("="*40)

# Final check of all created files in the output directory
print("\nFinal assets created in your Google Drive:")
# !ls -lh {OUTPUT_DIR}
# Out:
# --- Block 1: Setup and Initial Configuration ---
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All outputs will be saved to: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets
#
# --- GPU Check ---
# Found 1 GPU(s). Enabling memory growth.
# -------------------------
#
# --- Block 2: Data Loading and Preprocessing ---
# Combined dataset has 850849 rows.
# Processing 178 subject-activity groups for windowing...
# Created 56083 windows with shape (56083, 60, 6)
# Encoded 5 classes: [np.str_('A'), np.str_('B'), np.str_('C'), np.str_('D'), np.str_('E')]
# Feature scaling complete. Scaler is fit and ready.
#
# --- Block 3: TCN Model Definition and Training ---
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 60, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 60, 64)    │      2,752 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_10[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 60, 64)    │     28,736 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 60, 64)    │        448 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_11[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 60, 64)    │          0 │ conv1d_13[0][0],  │
# │                     │                   │            │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 60, 64)    │     28,736 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_12[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 60, 64)    │     28,736 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_13[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 60, 64)    │          0 │ add_5[0][0],      │
# │                     │                   │            │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 60, 64)    │     28,736 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_14[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 60, 64)    │     28,736 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_15[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 60, 64)    │          0 │ add_6[0][0],      │
# │                     │                   │            │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 60, 64)    │     28,736 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_16[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 60, 64)    │     28,736 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_17[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 60, 64)    │          0 │ add_7[0][0],      │
# │                     │                   │            │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 60, 64)    │     28,736 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_18[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 60, 64)    │     28,736 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 64)    │        256 │ conv1d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 60, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 60, 64)    │          0 │ activation_19[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 60, 64)    │          0 │ add_8[0][0],      │
# │                     │                   │            │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ add_9[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5)         │        325 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 264,709 (1.01 MB)
#  Trainable params: 263,429 (1.00 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Class weights computed: {0: np.float64(0.6842130947539651), 1: np.float64(0.9696173351775011), 2: np.float64(2.7772862330802246), 3: np.float64(0.9313994685562444), 4: np.float64(0.9316057585825027)}
# Epoch 1/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7788 - loss: 0.6656
# Epoch 1: val_accuracy improved from -inf to 0.94794, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.7789 - loss: 0.6651 - val_accuracy: 0.9479 - val_loss: 0.1427 - learning_rate: 0.0010
# Epoch 2/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9283 - loss: 0.1941
# Epoch 2: val_accuracy improved from 0.94794 to 0.95602, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.9283 - loss: 0.1941 - val_accuracy: 0.9560 - val_loss: 0.1187 - learning_rate: 0.0010
# Epoch 3/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9393 - loss: 0.1666
# Epoch 3: val_accuracy improved from 0.95602 to 0.96161, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9393 - loss: 0.1666 - val_accuracy: 0.9616 - val_loss: 0.0963 - learning_rate: 0.0010
# Epoch 4/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9410 - loss: 0.1501
# Epoch 4: val_accuracy improved from 0.96161 to 0.96494, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9410 - loss: 0.1501 - val_accuracy: 0.9649 - val_loss: 0.0887 - learning_rate: 0.0010
# Epoch 5/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9490 - loss: 0.1345
# Epoch 5: val_accuracy improved from 0.96494 to 0.96505, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9490 - loss: 0.1345 - val_accuracy: 0.9651 - val_loss: 0.0850 - learning_rate: 0.0010
# Epoch 6/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9515 - loss: 0.1197
# Epoch 6: val_accuracy improved from 0.96505 to 0.96755, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9516 - loss: 0.1197 - val_accuracy: 0.9676 - val_loss: 0.0775 - learning_rate: 0.0010
# Epoch 7/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9540 - loss: 0.1152
# Epoch 7: val_accuracy improved from 0.96755 to 0.97433, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9540 - loss: 0.1152 - val_accuracy: 0.9743 - val_loss: 0.0705 - learning_rate: 0.0010
# Epoch 8/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9613 - loss: 0.1045
# Epoch 8: val_accuracy did not improve from 0.97433
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9613 - loss: 0.1045 - val_accuracy: 0.9714 - val_loss: 0.0736 - learning_rate: 0.0010
# Epoch 9/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9614 - loss: 0.1061
# Epoch 9: val_accuracy did not improve from 0.97433
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9614 - loss: 0.1061 - val_accuracy: 0.9690 - val_loss: 0.0700 - learning_rate: 0.0010
# Epoch 10/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9614 - loss: 0.0997
# Epoch 10: val_accuracy improved from 0.97433 to 0.97730, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9614 - loss: 0.0997 - val_accuracy: 0.9773 - val_loss: 0.0624 - learning_rate: 0.0010
# Epoch 11/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9621 - loss: 0.1006
# Epoch 11: val_accuracy did not improve from 0.97730
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9621 - loss: 0.1006 - val_accuracy: 0.9627 - val_loss: 0.0867 - learning_rate: 0.0010
# Epoch 12/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9613 - loss: 0.0974
# Epoch 12: val_accuracy did not improve from 0.97730
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9614 - loss: 0.0974 - val_accuracy: 0.9748 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 13/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9647 - loss: 0.0952
# Epoch 13: val_accuracy improved from 0.97730 to 0.98122, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9647 - loss: 0.0951 - val_accuracy: 0.9812 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 14/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.0845
# Epoch 14: val_accuracy did not improve from 0.98122
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9667 - loss: 0.0845 - val_accuracy: 0.9743 - val_loss: 0.0596 - learning_rate: 0.0010
# Epoch 15/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9665 - loss: 0.0882
# Epoch 15: val_accuracy did not improve from 0.98122
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9665 - loss: 0.0882 - val_accuracy: 0.9800 - val_loss: 0.0551 - learning_rate: 0.0010
# Epoch 16/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9674 - loss: 0.0814
# Epoch 16: val_accuracy improved from 0.98122 to 0.98134, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9674 - loss: 0.0814 - val_accuracy: 0.9813 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 17/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9711 - loss: 0.0767
# Epoch 17: val_accuracy improved from 0.98134 to 0.98146, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9711 - loss: 0.0768 - val_accuracy: 0.9815 - val_loss: 0.0493 - learning_rate: 0.0010
# Epoch 18/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9704 - loss: 0.0761
# Epoch 18: val_accuracy improved from 0.98146 to 0.98562, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9704 - loss: 0.0761 - val_accuracy: 0.9856 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 19/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9685 - loss: 0.0845
# Epoch 19: val_accuracy did not improve from 0.98562
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9685 - loss: 0.0845 - val_accuracy: 0.9844 - val_loss: 0.0444 - learning_rate: 0.0010
# Epoch 20/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9706 - loss: 0.0765
# Epoch 20: val_accuracy did not improve from 0.98562
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9706 - loss: 0.0765 - val_accuracy: 0.9823 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 21/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9742 - loss: 0.0729
# Epoch 21: val_accuracy did not improve from 0.98562
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9742 - loss: 0.0729 - val_accuracy: 0.9851 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 22/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9715 - loss: 0.0724
# Epoch 22: val_accuracy did not improve from 0.98562
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9715 - loss: 0.0724 - val_accuracy: 0.9807 - val_loss: 0.0549 - learning_rate: 0.0010
# Epoch 23/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9745 - loss: 0.0675
# Epoch 23: val_accuracy did not improve from 0.98562
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9745 - loss: 0.0675 - val_accuracy: 0.9843 - val_loss: 0.0459 - learning_rate: 0.0010
# Epoch 24/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9743 - loss: 0.0689
# Epoch 24: val_accuracy improved from 0.98562 to 0.98954, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9743 - loss: 0.0689 - val_accuracy: 0.9895 - val_loss: 0.0322 - learning_rate: 5.0000e-04
# Epoch 25/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9786 - loss: 0.0585
# Epoch 25: val_accuracy did not improve from 0.98954
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9786 - loss: 0.0585 - val_accuracy: 0.9894 - val_loss: 0.0305 - learning_rate: 5.0000e-04
# Epoch 26/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9787 - loss: 0.0559
# Epoch 26: val_accuracy improved from 0.98954 to 0.99120, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9787 - loss: 0.0559 - val_accuracy: 0.9912 - val_loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 27/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9801 - loss: 0.0519
# Epoch 27: val_accuracy did not improve from 0.99120
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9801 - loss: 0.0519 - val_accuracy: 0.9912 - val_loss: 0.0283 - learning_rate: 5.0000e-04
# Epoch 28/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9776 - loss: 0.0612
# Epoch 28: val_accuracy improved from 0.99120 to 0.99156, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9776 - loss: 0.0611 - val_accuracy: 0.9916 - val_loss: 0.0273 - learning_rate: 5.0000e-04
# Epoch 29/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9788 - loss: 0.0562
# Epoch 29: val_accuracy improved from 0.99156 to 0.99287, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9788 - loss: 0.0562 - val_accuracy: 0.9929 - val_loss: 0.0275 - learning_rate: 5.0000e-04
# Epoch 30/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.0524
# Epoch 30: val_accuracy did not improve from 0.99287
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9823 - loss: 0.0524 - val_accuracy: 0.9908 - val_loss: 0.0284 - learning_rate: 5.0000e-04
# Epoch 31/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.0549
# Epoch 31: val_accuracy did not improve from 0.99287
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9824 - loss: 0.0549 - val_accuracy: 0.9913 - val_loss: 0.0288 - learning_rate: 5.0000e-04
# Epoch 32/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9811 - loss: 0.0496
# Epoch 32: val_accuracy did not improve from 0.99287
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9811 - loss: 0.0496 - val_accuracy: 0.9917 - val_loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 33/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9799 - loss: 0.0547
# Epoch 33: val_accuracy did not improve from 0.99287
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9799 - loss: 0.0547 - val_accuracy: 0.9905 - val_loss: 0.0273 - learning_rate: 5.0000e-04
# Epoch 34/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9821 - loss: 0.0503
# Epoch 34: val_accuracy did not improve from 0.99287
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9821 - loss: 0.0502 - val_accuracy: 0.9916 - val_loss: 0.0255 - learning_rate: 2.5000e-04
# Epoch 35/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.0491
# Epoch 35: val_accuracy did not improve from 0.99287
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9823 - loss: 0.0490 - val_accuracy: 0.9925 - val_loss: 0.0230 - learning_rate: 2.5000e-04
# Epoch 36/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9851 - loss: 0.0416
# Epoch 36: val_accuracy improved from 0.99287 to 0.99311, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9851 - loss: 0.0416 - val_accuracy: 0.9931 - val_loss: 0.0237 - learning_rate: 2.5000e-04
# Epoch 37/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9841 - loss: 0.0442
# Epoch 37: val_accuracy did not improve from 0.99311
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9841 - loss: 0.0442 - val_accuracy: 0.9929 - val_loss: 0.0210 - learning_rate: 2.5000e-04
# Epoch 38/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9846 - loss: 0.0414
# Epoch 38: val_accuracy did not improve from 0.99311
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9846 - loss: 0.0414 - val_accuracy: 0.9918 - val_loss: 0.0231 - learning_rate: 2.5000e-04
# Epoch 39/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9851 - loss: 0.0439
# Epoch 39: val_accuracy improved from 0.99311 to 0.99358, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9851 - loss: 0.0439 - val_accuracy: 0.9936 - val_loss: 0.0206 - learning_rate: 2.5000e-04
# Epoch 40/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9839 - loss: 0.0438
# Epoch 40: val_accuracy did not improve from 0.99358
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9839 - loss: 0.0438 - val_accuracy: 0.9931 - val_loss: 0.0212 - learning_rate: 2.5000e-04
# Epoch 41/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9847 - loss: 0.0412
# Epoch 41: val_accuracy did not improve from 0.99358
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9847 - loss: 0.0412 - val_accuracy: 0.9930 - val_loss: 0.0206 - learning_rate: 2.5000e-04
# Epoch 42/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9842 - loss: 0.0421
# Epoch 42: val_accuracy did not improve from 0.99358
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9842 - loss: 0.0420 - val_accuracy: 0.9929 - val_loss: 0.0211 - learning_rate: 2.5000e-04
# Epoch 43/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9849 - loss: 0.0405
# Epoch 43: val_accuracy improved from 0.99358 to 0.99418, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9849 - loss: 0.0405 - val_accuracy: 0.9942 - val_loss: 0.0192 - learning_rate: 2.5000e-04
# Epoch 44/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9850 - loss: 0.0386
# Epoch 44: val_accuracy did not improve from 0.99418
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9850 - loss: 0.0386 - val_accuracy: 0.9933 - val_loss: 0.0188 - learning_rate: 2.5000e-04
# Epoch 45/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0404
# Epoch 45: val_accuracy did not improve from 0.99418
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9857 - loss: 0.0404 - val_accuracy: 0.9942 - val_loss: 0.0188 - learning_rate: 2.5000e-04
# Epoch 46/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9849 - loss: 0.0379
# Epoch 46: val_accuracy improved from 0.99418 to 0.99453, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9849 - loss: 0.0379 - val_accuracy: 0.9945 - val_loss: 0.0183 - learning_rate: 2.5000e-04
# Epoch 47/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0409
# Epoch 47: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9854 - loss: 0.0408 - val_accuracy: 0.9927 - val_loss: 0.0199 - learning_rate: 2.5000e-04
# Epoch 48/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9866 - loss: 0.0360
# Epoch 48: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9866 - loss: 0.0360 - val_accuracy: 0.9932 - val_loss: 0.0178 - learning_rate: 2.5000e-04
# Epoch 49/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0404
# Epoch 49: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9857 - loss: 0.0404 - val_accuracy: 0.9943 - val_loss: 0.0176 - learning_rate: 2.5000e-04
# Epoch 50/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9868 - loss: 0.0398
# Epoch 50: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9868 - loss: 0.0398 - val_accuracy: 0.9937 - val_loss: 0.0187 - learning_rate: 2.5000e-04
# Epoch 51/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9859 - loss: 0.0411
# Epoch 51: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9859 - loss: 0.0410 - val_accuracy: 0.9944 - val_loss: 0.0167 - learning_rate: 2.5000e-04
# Epoch 52/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0352
# Epoch 52: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9878 - loss: 0.0352 - val_accuracy: 0.9938 - val_loss: 0.0184 - learning_rate: 2.5000e-04
# Epoch 53/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9864 - loss: 0.0373
# Epoch 53: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9864 - loss: 0.0373 - val_accuracy: 0.9944 - val_loss: 0.0172 - learning_rate: 2.5000e-04
# Epoch 54/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9861 - loss: 0.0377
# Epoch 54: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9861 - loss: 0.0377 - val_accuracy: 0.9944 - val_loss: 0.0176 - learning_rate: 2.5000e-04
# Epoch 55/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0345
# Epoch 55: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9878 - loss: 0.0345 - val_accuracy: 0.9944 - val_loss: 0.0159 - learning_rate: 2.5000e-04
# Epoch 56/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0352
# Epoch 56: val_accuracy did not improve from 0.99453
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9874 - loss: 0.0352 - val_accuracy: 0.9944 - val_loss: 0.0156 - learning_rate: 2.5000e-04
# Epoch 57/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9873 - loss: 0.0328
# Epoch 57: val_accuracy improved from 0.99453 to 0.99501, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9873 - loss: 0.0328 - val_accuracy: 0.9950 - val_loss: 0.0161 - learning_rate: 2.5000e-04
# Epoch 58/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0334
# Epoch 58: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9874 - loss: 0.0334 - val_accuracy: 0.9942 - val_loss: 0.0179 - learning_rate: 2.5000e-04
# Epoch 59/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9866 - loss: 0.0346
# Epoch 59: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9866 - loss: 0.0346 - val_accuracy: 0.9950 - val_loss: 0.0172 - learning_rate: 2.5000e-04
# Epoch 60/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9882 - loss: 0.0338
# Epoch 60: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9882 - loss: 0.0338 - val_accuracy: 0.9948 - val_loss: 0.0161 - learning_rate: 2.5000e-04
# Epoch 61/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9884 - loss: 0.0327
# Epoch 61: val_accuracy improved from 0.99501 to 0.99536, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9884 - loss: 0.0327 - val_accuracy: 0.9954 - val_loss: 0.0154 - learning_rate: 2.5000e-04
# Epoch 62/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9882 - loss: 0.0318
# Epoch 62: val_accuracy did not improve from 0.99536
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9882 - loss: 0.0319 - val_accuracy: 0.9949 - val_loss: 0.0172 - learning_rate: 2.5000e-04
# Epoch 63/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9871 - loss: 0.0332
# Epoch 63: val_accuracy did not improve from 0.99536
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9871 - loss: 0.0332 - val_accuracy: 0.9949 - val_loss: 0.0167 - learning_rate: 2.5000e-04
# Epoch 64/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - loss: 0.0330
# Epoch 64: val_accuracy improved from 0.99536 to 0.99632, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9875 - loss: 0.0329 - val_accuracy: 0.9963 - val_loss: 0.0142 - learning_rate: 2.5000e-04
# Epoch 65/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9901 - loss: 0.0306
# Epoch 65: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9901 - loss: 0.0306 - val_accuracy: 0.9954 - val_loss: 0.0154 - learning_rate: 2.5000e-04
# Epoch 66/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9901 - loss: 0.0286
# Epoch 66: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9901 - loss: 0.0286 - val_accuracy: 0.9960 - val_loss: 0.0147 - learning_rate: 2.5000e-04
# Epoch 67/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9911 - loss: 0.0277
# Epoch 67: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9911 - loss: 0.0277 - val_accuracy: 0.9957 - val_loss: 0.0154 - learning_rate: 2.5000e-04
# Epoch 68/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9888 - loss: 0.0317
# Epoch 68: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9888 - loss: 0.0317 - val_accuracy: 0.9956 - val_loss: 0.0145 - learning_rate: 2.5000e-04
# Epoch 69/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9884 - loss: 0.0307
# Epoch 69: val_accuracy did not improve from 0.99632
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9884 - loss: 0.0307 - val_accuracy: 0.9951 - val_loss: 0.0160 - learning_rate: 2.5000e-04
# Epoch 70/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9899 - loss: 0.0293
# Epoch 70: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9899 - loss: 0.0293 - val_accuracy: 0.9950 - val_loss: 0.0148 - learning_rate: 1.2500e-04
# Epoch 71/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.0259
# Epoch 71: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9902 - loss: 0.0259 - val_accuracy: 0.9960 - val_loss: 0.0136 - learning_rate: 1.2500e-04
# Epoch 72/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0286
# Epoch 72: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9898 - loss: 0.0286 - val_accuracy: 0.9957 - val_loss: 0.0141 - learning_rate: 1.2500e-04
# Epoch 73/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9910 - loss: 0.0270
# Epoch 73: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9910 - loss: 0.0270 - val_accuracy: 0.9962 - val_loss: 0.0143 - learning_rate: 1.2500e-04
# Epoch 74/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0256
# Epoch 74: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9913 - loss: 0.0256 - val_accuracy: 0.9956 - val_loss: 0.0138 - learning_rate: 1.2500e-04
# Epoch 75/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9911 - loss: 0.0246
# Epoch 75: val_accuracy did not improve from 0.99632
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9911 - loss: 0.0247 - val_accuracy: 0.9960 - val_loss: 0.0140 - learning_rate: 1.2500e-04
# Epoch 76/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0268
# Epoch 76: val_accuracy improved from 0.99632 to 0.99655, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9907 - loss: 0.0268 - val_accuracy: 0.9966 - val_loss: 0.0138 - learning_rate: 1.2500e-04
# Epoch 77/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9903 - loss: 0.0267
# Epoch 77: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9903 - loss: 0.0267 - val_accuracy: 0.9963 - val_loss: 0.0132 - learning_rate: 6.2500e-05
# Epoch 78/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9905 - loss: 0.0280
# Epoch 78: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9905 - loss: 0.0280 - val_accuracy: 0.9963 - val_loss: 0.0136 - learning_rate: 6.2500e-05
# Epoch 79/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9910 - loss: 0.0254
# Epoch 79: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9910 - loss: 0.0254 - val_accuracy: 0.9962 - val_loss: 0.0133 - learning_rate: 6.2500e-05
# Epoch 80/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9916 - loss: 0.0251
# Epoch 80: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9916 - loss: 0.0251 - val_accuracy: 0.9961 - val_loss: 0.0135 - learning_rate: 6.2500e-05
# Epoch 81/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9912 - loss: 0.0254
# Epoch 81: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9912 - loss: 0.0254 - val_accuracy: 0.9962 - val_loss: 0.0130 - learning_rate: 6.2500e-05
# Epoch 82/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9908 - loss: 0.0250
# Epoch 82: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9908 - loss: 0.0250 - val_accuracy: 0.9958 - val_loss: 0.0132 - learning_rate: 6.2500e-05
# Epoch 83/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0238
# Epoch 83: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9916 - loss: 0.0238 - val_accuracy: 0.9963 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 84/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.0277
# Epoch 84: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9903 - loss: 0.0277 - val_accuracy: 0.9964 - val_loss: 0.0131 - learning_rate: 6.2500e-05
# Epoch 85/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9900 - loss: 0.0272
# Epoch 85: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9900 - loss: 0.0272 - val_accuracy: 0.9963 - val_loss: 0.0128 - learning_rate: 6.2500e-05
# Epoch 86/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0238
# Epoch 86: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9919 - loss: 0.0238 - val_accuracy: 0.9963 - val_loss: 0.0133 - learning_rate: 6.2500e-05
# Epoch 87/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0261
# Epoch 87: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9919 - loss: 0.0261 - val_accuracy: 0.9966 - val_loss: 0.0128 - learning_rate: 6.2500e-05
# Epoch 88/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9916 - loss: 0.0231
# Epoch 88: val_accuracy did not improve from 0.99655
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9916 - loss: 0.0231 - val_accuracy: 0.9966 - val_loss: 0.0127 - learning_rate: 6.2500e-05
# Epoch 89/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0228
# Epoch 89: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9916 - loss: 0.0228 - val_accuracy: 0.9964 - val_loss: 0.0125 - learning_rate: 3.1250e-05
# Epoch 90/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9923 - loss: 0.0237
# Epoch 90: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9923 - loss: 0.0238 - val_accuracy: 0.9963 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 91/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0258
# Epoch 91: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9913 - loss: 0.0258 - val_accuracy: 0.9966 - val_loss: 0.0123 - learning_rate: 3.1250e-05
# Epoch 92/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9901 - loss: 0.0256
# Epoch 92: val_accuracy did not improve from 0.99655
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9901 - loss: 0.0256 - val_accuracy: 0.9966 - val_loss: 0.0125 - learning_rate: 3.1250e-05
# Epoch 93/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9921 - loss: 0.0226
# Epoch 93: val_accuracy improved from 0.99655 to 0.99679, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9921 - loss: 0.0226 - val_accuracy: 0.9968 - val_loss: 0.0122 - learning_rate: 3.1250e-05
# Epoch 94/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9917 - loss: 0.0230
# Epoch 94: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9917 - loss: 0.0230 - val_accuracy: 0.9968 - val_loss: 0.0122 - learning_rate: 3.1250e-05
# Epoch 95/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9923 - loss: 0.0231
# Epoch 95: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9922 - loss: 0.0231 - val_accuracy: 0.9963 - val_loss: 0.0127 - learning_rate: 3.1250e-05
# Epoch 96/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9920 - loss: 0.0231
# Epoch 96: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9920 - loss: 0.0231 - val_accuracy: 0.9962 - val_loss: 0.0127 - learning_rate: 3.1250e-05
# Epoch 97/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9908 - loss: 0.0235
# Epoch 97: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9908 - loss: 0.0235 - val_accuracy: 0.9964 - val_loss: 0.0127 - learning_rate: 3.1250e-05
# Epoch 98/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0221
# Epoch 98: val_accuracy did not improve from 0.99679
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9916 - loss: 0.0221 - val_accuracy: 0.9964 - val_loss: 0.0122 - learning_rate: 3.1250e-05
# Epoch 99/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9920 - loss: 0.0238
# Epoch 99: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9920 - loss: 0.0238 - val_accuracy: 0.9964 - val_loss: 0.0120 - learning_rate: 1.5625e-05
# Epoch 100/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9921 - loss: 0.0231
# Epoch 100: val_accuracy did not improve from 0.99679
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9921 - loss: 0.0231 - val_accuracy: 0.9964 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 99.
#
# --- Block 4: Keras Model Evaluation (Benchmark) ---
# Loading best Keras model weights saved during training...
# Keras Test Accuracy (Ground Truth): 0.9965
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#
# Keras Model Classification Report:
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00      4099
#            B       1.00      1.00      1.00      2892
#            C       0.99      1.00      1.00      1010
#            D       1.00      0.99      0.99      3010
#            E       0.99      1.00      0.99      3010
#
#     accuracy                           1.00     14021
#    macro avg       1.00      1.00      1.00     14021
# weighted avg       1.00      1.00      1.00     14021
#
#
# --- Saving the definitive test set artifacts ---
# Definitive test set saved to: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/definitive_test_set
#
# --- Block 5: Exporting Assets for Android (TFLite, JSON) ---
# Scaler saved to: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_scaler.json
# Labels saved to: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_labels.json
# Starting TFLite conversion with full integer quantization...
# Saved artifact at '/tmp/tmphz4txs5t'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 6), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   137685651899216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651900176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651899792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651900560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651903440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651901136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651901904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651902288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588359120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588358352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651901712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685651902096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588355856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588353744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588357968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588356624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588357008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588355280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588355472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588356432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588345488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588358928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588360272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588354896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588361040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685588359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598799824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598800016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598798480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598799632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598802512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598805200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598805392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598804624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598803472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598805008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598804432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598807888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598808080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598807312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598806160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598807120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598810576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598810768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598810000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598808848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598810384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598809808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598813264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598813840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598811920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598811536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685598813072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685590016848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137685590018192: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Quantized TFLite model saved to: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_v2_with_Assets/tcn_v2_ABCDE_har_model.tflite
#
# --- Block 6: TFLite Model Verification ---
# TFLite model loaded. Verifying performance on the test set...
#
# TFLite Model Test Accuracy: 0.9939
#
# TFLite Model Classification Report:
#               precision    recall  f1-score   support
#
#            A       1.00      0.99      1.00      4099
#            B       1.00      1.00      1.00      2892
#            C       0.99      1.00      0.99      1010
#            D       0.99      0.99      0.99      3010
#            E       0.98      1.00      0.99      3010
#
#     accuracy                           0.99     14021
#    macro avg       0.99      0.99      0.99     14021
# weighted avg       0.99      0.99      0.99     14021
#
#
# --- Block 7: Final Report ---
# ========================================
#   VERIFICATION AND ACCURACY REPORT
# ========================================
# Original Keras Model Accuracy: 0.9965
# Quantized TFLite Model Accuracy: 0.9939
# Accuracy Drop: 0.0026 (0.26%)
#
# VERDICT: SUCCESS! The TFLite model's accuracy is very close to the original.
# The assets are consistent and ready for deployment.
# ========================================
#
# Final assets created in your Google Drive:
# total 3.6M
# drwx------ 2 root root 4.0K Jul 15 04:26 Converted_Assets
# drwx------ 2 root root 4.0K Jul 31 06:08 definitive_test_set
# -rw------- 1 root root 3.3M Jul 31 06:07 tcn_v2_ABCDE_har_model.keras
# -rw------- 1 root root 302K Jul 31 06:08 tcn_v2_ABCDE_har_model.tflite
# -rw------- 1 root root   72 Jul 31 06:08 tcn_v2_ABCDE_labels.json
# -rw------- 1 root root  384 Jul 31 06:08 tcn_v2_ABCDE_scaler.json
